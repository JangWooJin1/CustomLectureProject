# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 시간표(.xlsx)불러오기

# %%
df = pd.read_excel("종합강의시간표목록.xlsx") 

df.head()
# Out:
# c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    번호 학년/가진급학년  교과과정     교과영역구분      학수강좌번호       교과목명  교원명 수업캠퍼스  \
# 0   1    1,2학년  학문기초  제4영역:자연과학  PRI4001-01   미적분학및연습1  문환표    서울
# 1   2    1,2학년  학문기초  제4영역:자연과학  PRI4001-02   미적분학및연습1  박장희    서울
# 2   3    1,2학년  학문기초  제4영역:자연과학  PRI4002-01  일반물리학및실험1  조훈영    서울
# 3   4    1,2학년  학문기초  제4영역:자연과학  PRI4012-01   미적분학및연습2  엄건애    서울
# 4   5    1,2학년  학문기초  제4영역:자연과학  PRI4012-02   미적분학및연습2  최광호    서울
#
#                                        요일/시간  \
# 0                                        NaN
# 1  월4.0-5.0/12:00-13:30,수3.0-4.0/11:00-12:30
# 2                      월7.0-11.5/15:00-19:40
# 3  월4.0-5.0/12:00-13:30,수3.0-4.0/11:00-12:30
# 4  월4.0-5.0/12:00-13:30,수3.0-4.0/11:00-12:30
#
#                                                  강의실  ...  혁신교과목구분  원어강의  \
# 0                                                NaN  ...     MOOC   NaN
# 1  102-352(학술/문화관 K352 352 강의실),102-352(학술/문화관 K3...  ...      NaN   NaN
# 2                              307-309(명진관 A309 강의실)  ...      NaN   NaN
# 3  407-109(정보문화관P P304 강의실),407-109(정보문화관P P304 강의실)  ...      NaN   NaN
# 4  102-217(학술/문화관 K217 217 강의실),102-217(학술/문화관 K2...  ...      NaN   NaN
#
#    강평결과  이수구분 강의미리보기  개설대학        개설학과/전공 집중이수학기구분                비고  \
# 0   NaN    학기    NaN  이과대학       이과대학 수학과      NaN             사이버강의
# 1   NaN    학기    NaN  이과대학       이과대학 수학과      NaN               NaN
# 2   NaN    학기    NaN  이과대학  이과대학 물리반도체과학부      NaN     팀티칭, 수강정원 50명
# 3   NaN    학기    NaN  이과대학       이과대학 수학과      NaN               NaN
# 4   NaN    학기    NaN  이과대학       이과대학 수학과      NaN  공과대 일괄수강신청 예정 강좌
#
#                               교과목영문명
# 0                          Calculus1
# 1                          Calculus1
# 2  General Physics and Experiments I
# 3                          Calculus2
# 4                          Calculus2
#
# [5 rows x 28 columns]

# %% [markdown]
# 종합강의시간표에서 필요없는 컬럼 제거

# %%
drop_list = ["학년/가진급학년", "이론", "실습", "공학설계", "강의계획서"
             ,"교과목해설", "강의유형", "혁신교과목구분", "원어강의", "강평결과",
             "이수구분", "강의미리보기", "집중이수학기구분", "교과목영문명", "강의종류" ]

df.drop(columns=drop_list, inplace=True)
#df.set_index("번호", inplace=True)


df.head()
# Out:
#    번호  교과과정     교과영역구분      학수강좌번호       교과목명  교원명 수업캠퍼스  \
# 0   1  학문기초  제4영역:자연과학  PRI4001-01   미적분학및연습1  문환표    서울
# 1   2  학문기초  제4영역:자연과학  PRI4001-02   미적분학및연습1  박장희    서울
# 2   3  학문기초  제4영역:자연과학  PRI4002-01  일반물리학및실험1  조훈영    서울
# 3   4  학문기초  제4영역:자연과학  PRI4012-01   미적분학및연습2  엄건애    서울
# 4   5  학문기초  제4영역:자연과학  PRI4012-02   미적분학및연습2  최광호    서울
#
#                                        요일/시간  \
# 0                                        NaN
# 1  월4.0-5.0/12:00-13:30,수3.0-4.0/11:00-12:30
# 2                      월7.0-11.5/15:00-19:40
# 3  월4.0-5.0/12:00-13:30,수3.0-4.0/11:00-12:30
# 4  월4.0-5.0/12:00-13:30,수3.0-4.0/11:00-12:30
#
#                                                  강의실  학점  개설대학        개설학과/전공  \
# 0                                                NaN   3  이과대학       이과대학 수학과
# 1  102-352(학술/문화관 K352 352 강의실),102-352(학술/문화관 K3...   3  이과대학       이과대학 수학과
# 2                              307-309(명진관 A309 강의실)   4  이과대학  이과대학 물리반도체과학부
# 3  407-109(정보문화관P P304 강의실),407-109(정보문화관P P304 강의실)   3  이과대학       이과대학 수학과
# 4  102-217(학술/문화관 K217 217 강의실),102-217(학술/문화관 K2...   3  이과대학       이과대학 수학과
#
#                  비고
# 0             사이버강의
# 1               NaN
# 2     팀티칭, 수강정원 50명
# 3               NaN
# 4  공과대 일괄수강신청 예정 강좌

# %% [markdown]
# 복합값인 '학수강좌번호' 분리해서 저장 (제1정규형)

# %%
df[['학수코드', '학수번호']] = df['학수강좌번호'].str.split('-', n=1, expand=True)

df.drop(columns=["학수강좌번호"], inplace=True)

df.head()
# Out:
#    번호  교과과정     교과영역구분       교과목명  교원명 수업캠퍼스  \
# 0   1  학문기초  제4영역:자연과학   미적분학및연습1  문환표    서울
# 1   2  학문기초  제4영역:자연과학   미적분학및연습1  박장희    서울
# 2   3  학문기초  제4영역:자연과학  일반물리학및실험1  조훈영    서울
# 3   4  학문기초  제4영역:자연과학   미적분학및연습2  엄건애    서울
# 4   5  학문기초  제4영역:자연과학   미적분학및연습2  최광호    서울
#
#                                        요일/시간  \
# 0                                        NaN
# 1  월4.0-5.0/12:00-13:30,수3.0-4.0/11:00-12:30
# 2                      월7.0-11.5/15:00-19:40
# 3  월4.0-5.0/12:00-13:30,수3.0-4.0/11:00-12:30
# 4  월4.0-5.0/12:00-13:30,수3.0-4.0/11:00-12:30
#
#                                                  강의실  학점  개설대학        개설학과/전공  \
# 0                                                NaN   3  이과대학       이과대학 수학과
# 1  102-352(학술/문화관 K352 352 강의실),102-352(학술/문화관 K3...   3  이과대학       이과대학 수학과
# 2                              307-309(명진관 A309 강의실)   4  이과대학  이과대학 물리반도체과학부
# 3  407-109(정보문화관P P304 강의실),407-109(정보문화관P P304 강의실)   3  이과대학       이과대학 수학과
# 4  102-217(학술/문화관 K217 217 강의실),102-217(학술/문화관 K2...   3  이과대학       이과대학 수학과
#
#                  비고     학수코드 학수번호
# 0             사이버강의  PRI4001   01
# 1               NaN  PRI4001   02
# 2     팀티칭, 수강정원 50명  PRI4002   01
# 3               NaN  PRI4012   01
# 4  공과대 일괄수강신청 예정 강좌  PRI4012   02

# %% [markdown]
# 컬럼 순서 변경

# %%
print(df.columns.tolist())
# Out:
# ['번호', '교과과정', '교과영역구분', '교과목명', '교원명', '수업캠퍼스', '요일/시간', '강의실', '학점', '개설대학', '개설학과/전공', '비고', '학수코드', '학수번호']

# %%
new_order = ['번호', '교과과정', '교과영역구분',  '학수코드', '학수번호',  '교과목명', '교원명', '수업캠퍼스', '요일/시간', '강의실', '학점', '개설대학', '개설학과/전공', '비고']
df = df.reindex(columns=new_order)

print(df.to_string(index=False))
# Out:
#   번호   교과과정     교과영역구분     학수코드 학수번호                                                           교과목명         교원명 수업캠퍼스                                                                                요일/시간                                                                                                                                                     강의실  학점     개설대학                           개설학과/전공                                                                                                  비고
#    1   학문기초  제4영역:자연과학  PRI4001   01                                                       미적분학및연습1         문환표    서울                                                                                  NaN                                                                                                                                                     NaN   3     이과대학                          이과대학 수학과                                                                                               사이버강의
#    2   학문기초  제4영역:자연과학  PRI4001   02                                                       미적분학및연습1         박장희    서울                                            월4.0-5.0/12:00-13:30,수3.0-4.0/11:00-12:30                                                                                               102-352(학술/문화관 K352 352 강의실),102-352(학술/문화관 K352 352 강의실)   3     이과대학                          이과대학 수학과                                                                                                 NaN
#    3   학문기초  제4영역:자연과학  PRI4002   01                                                      일반물리학및실험1         조훈영    서울                                                                월7.0-11.5/15:00-19:40                                                                                                                                   307-309(명진관 A309 강의실)   4     이과대학                     이과대학 물리반도체과학부                                                                                       팀티칭, 수강정원 50명
#    4   학문기초  제4영역:자연과학  PRI4012   01                                                       미적분학및연습2         엄건애    서울                                            월4.0-5.0/12:00-13:30,수3.0-4.0/11:00-12:30                                                                                                       407-109(정보문화관P P304 강의실),407-109(정보문화관P P304 강의실)   3     이과대학                          이과대학 수학과                                                                                                 NaN
#    5   학문기초  제4영역:자연과학  PRI4012   02                                                       미적분학및연습2         최광호    서울                                            월4.0-5.0/12:00-13:30,수3.0-4.0/11:00-12:30                                                                                               102-217(학술/문화관 K217 217 강의실),102-217(학술/문화관 K217 217 강의실)   3     이과대학                          이과대학 수학과                                                                                    공과대 일괄수강신청 예정 강좌
#    6   학문기초  제4영역:자연과학  PRI4012   03                                                       미적분학및연습2         임영빈    서울                                            월4.0-5.0/12:00-13:30,수3.0-4.0/11:00-12:30                                                                                                     407-B105(정보문화관P P202 강의실),407-B105(정보문화관P P202 강의실)   3     이과대학                          이과대학 수학과                                                                                    공과대 일괄수강신청 예정 강좌
#    7   학문기초  제4영역:자연과학  PRI4012   04                                                       미적분학및연습2         심호진    서울                                            월8.5-9.5/16:30-18:00,수6.0-7.0/14:00-15:30                                                                                                       207-512(혜화관 512 512 강의실),207-514(혜화관 514 514 강의실)   3     이과대학                          이과대학 수학과                                                                                    공과대 일괄수강신청 예정 강좌
#    8   학문기초  제4영역:자연과학  PRI4012   05                                                       미적분학및연습2         김동호    서울                                            화6.0-7.0/14:00-15:30,목6.0-7.0/14:00-15:30                                                                                                       207-315(혜화관 315 315 강의실),207-315(혜화관 315 315 강의실)   3     이과대학                          이과대학 수학과                                                                                    공과대 일괄수강신청 예정 강좌
#    9   학문기초  제4영역:자연과학  PRI4012   06                                                       미적분학및연습2         엄건애    서울                                            수4.5-5.5/12:30-14:00,금4.0-5.0/12:00-13:30                                                                                                     407-B101(정보문화관P P201 강의실),407-B101(정보문화관P P201 강의실)   3     이과대학                          이과대학 수학과                                                                                    공과대 일괄수강신청 예정 강좌
#   10   학문기초  제4영역:자연과학  PRI4012   07                                                       미적분학및연습2         임영빈    서울                                            화4.0-5.0/12:00-13:30,목4.0-5.0/12:00-13:30                                                                                                     407-B101(정보문화관P P201 강의실),407-B101(정보문화관P P201 강의실)   3     이과대학                          이과대학 수학과                                                                                                 NaN
#   11   학문기초  제4영역:자연과학  PRI4012   08                                                       미적분학및연습2         박장희    서울                                            화4.0-5.0/12:00-13:30,목4.0-5.0/12:00-13:30                                                                                               102-456(학술/문화관 K456 456 강의실),102-456(학술/문화관 K456 456 강의실)   3     이과대학                          이과대학 수학과                                                                                    공과대 일괄수강신청 예정 강좌
#   12   학문기초  제4영역:자연과학  PRI4012   09                                                       미적분학및연습2         박정준    서울                                            화4.0-5.0/12:00-13:30,목4.0-5.0/12:00-13:30                                                                                                   201-117(사회과학/경영관 M117 강의실),201-117(사회과학/경영관 M117 강의실)   3     이과대학                          이과대학 수학과                                                                                    공과대 일괄수강신청 예정 강좌
#   13   학문기초  제4영역:자연과학  PRI4012   10                                                       미적분학및연습2         박상웅    서울                                                               수10.0-12.5/18:00-20:30                                                                                                                                   307-336(명진관 A336 강의실)   3     이과대학                          이과대학 수학과                                                                                                 NaN
#   14   학문기초  제4영역:자연과학  PRI4012   11                                                       미적분학및연습2         임영빈    서울                                            화6.0-7.0/14:00-15:30,목7.0-8.0/15:00-16:30                                                                                                     407-B105(정보문화관P P202 강의실),407-B108(정보문화관P P203 강의실)   3     이과대학                          이과대학 수학과                                                                                                 NaN
#   15   학문기초  제4영역:자연과학  PRI4012   12                                                       미적분학및연습2         권기운    서울                                            화6.0-7.0/14:00-15:30,목6.0-7.0/14:00-15:30                                                                                               102-352(학술/문화관 K352 352 강의실),102-352(학술/문화관 K352 352 강의실)   3     이과대학                          이과대학 수학과                                                                                   팀티칭, 혁신교수법-에듀테크러닝
#   16   학문기초  제4영역:자연과학  PRI4012   13                                                       미적분학및연습2          박호    서울                                            화6.0-7.0/14:00-15:30,목6.0-7.0/14:00-15:30                                                                                                   201-226(사회과학/경영관 M216 강의실),201-226(사회과학/경영관 M216 강의실)   3     이과대학                          이과대학 수학과                                                                                    공과대 일괄수강신청 예정 강좌
#   17   학문기초  제4영역:자연과학  PRI4012   14                                                       미적분학및연습2         박정준    서울                                            화8.0-9.0/16:00-17:30,목8.5-9.5/16:30-18:00                                                                                               102-356(학술/문화관 K356 356 강의실),102-356(학술/문화관 K356 356 강의실)   3     이과대학                          이과대학 수학과                                                                                                 NaN
#   18   학문기초  제4영역:자연과학  PRI4012   15                                                       미적분학및연습2         임영빈    서울                                            화8.0-9.0/16:00-17:30,목8.5-9.5/16:30-18:00                                                                                                             501-142(학림관 J104 강의실),501-142(학림관 J104 강의실)   3     이과대학                          이과대학 수학과                                                                                                 NaN
#   19   학문기초  제4영역:자연과학  PRI4012   16                                                       미적분학및연습2         조영덕    서울                                            수4.5-5.5/12:30-14:00,금4.0-5.0/12:00-13:30                                                                                         407-106(정보문화관P P303 정보 PBL_스마트),407-106(정보문화관P P303 정보 PBL_스마트)   3     이과대학                          이과대학 수학과                                                                                        혁신교수법-에듀테크러닝
#   20   학문기초  제4영역:자연과학  PRI4012   17                                                       미적분학및연습2          박호    서울                                                               화10.0-12.5/18:00-20:30                                                                                                                                   307-336(명진관 A336 강의실)   3     이과대학                          이과대학 수학과                                                                                                 NaN
#   21   학문기초  제4영역:자연과학  PRI4012   18                                                       미적분학및연습2         오승익    서울                                                               수10.0-12.5/18:00-20:30                                                                                                                            102-342(학술/문화관 K342 342 강의실)   3     이과대학                          이과대학 수학과                                                                                                 NaN
#   22   학문기초  제4영역:자연과학  PRI4012   19                                                       미적분학및연습2         조영덕    서울                                                               월10.0-12.5/18:00-20:30                                                                                                                               407-B105(정보문화관P P202 강의실)   3     이과대학                          이과대학 수학과                                                                                                 NaN
#   23   학문기초  제4영역:자연과학  PRI4012   20                                                       미적분학및연습2          박호    일산                                                                목8.0-10.5/16:00-18:50                                                                                                                                 1102-209(종합강의동 209 강의실)   3     이과대학                          이과대학 수학과                                                                        BMC개설, 바이오시스템 대학 일괄수강신청 예정강좌
#   24   학문기초  제4영역:자연과학  PRI4013   01                                                      일반물리학및실험2         정권범    서울                       월1.0-2.5/09:00-11:00,월4.0-5.0/12:00-13:30,수3.0-4.0/11:00-12:30                                                                                     308-325(과학관  일반물리학실험실A),308-305(과학관 D305 강의실),308-305(과학관 D305 강의실)   4     이과대학                     이과대학 물리반도체과학부                                                                     물리반도체과학부 신입생 일괄수강신청예정, 수강인원 50명
#   25   학문기초  제4영역:자연과학  PRI4013   02                                                      일반물리학및실험2         양우철    서울                       월4.0-5.0/12:00-13:30,수1.0-2.5/09:00-11:00,수3.0-4.0/11:00-12:30                                                                                     308-303(과학관 D303 강의실),308-303(과학관 D303 강의실),308-325(과학관  일반물리학실험실A)   4     이과대학                     이과대학 물리반도체과학부                                                                     물리반도체과학부 신입생 일괄수강신청예정, 수강인원 50명
#   26   학문기초  제4영역:자연과학  PRI4013   03                                                      일반물리학및실험2         김선배    서울                                        월10.0-12.5/18:00-20:30,월13.0-14.5/20:40-22:20                                                                                                           308-303(과학관 D303 강의실),308-325(과학관  일반물리학실험실A)   4     이과대학                     이과대학 물리반도체과학부                                                                          공과대 일괄수강신청 예정 강좌, 수강인원 50명
#   27   학문기초  제4영역:자연과학  PRI4013   04                                                      일반물리학및실험2         곽동욱    서울                                        화10.0-12.5/18:00-20:30,화13.0-14.5/20:40-22:20                                                                                                           308-303(과학관 D303 강의실),308-325(과학관  일반물리학실험실A)   4     이과대학                     이과대학 물리반도체과학부                                                                                            수강인원 50명
#   28   학문기초  제4영역:자연과학  PRI4013   05                                                      일반물리학및실험2         손정인    서울                       화8.0-9.0/16:00-17:30,목8.5-9.5/16:30-18:00,금1.0-2.5/09:00-11:00                                                                                     308-305(과학관 D305 강의실),308-305(과학관 D305 강의실),308-325(과학관  일반물리학실험실A)   4     이과대학                     이과대학 물리반도체과학부                                                                                            수강인원 50명
#   29   학문기초  제4영역:자연과학  PRI4013   06                                                      일반물리학및실험2         이원철    서울                       화4.0-5.0/12:00-13:30,목1.0-2.5/09:00-11:00,목4.0-5.0/12:00-13:30                                                                       102-357(학술/문화관 K357 357 강의실),308-325(과학관  일반물리학실험실A),102-357(학술/문화관 K357 357 강의실)   4     이과대학                     이과대학 물리반도체과학부                                                                          공과대 일괄수강신청 예정 강좌, 수강인원 50명
#   30   학문기초  제4영역:자연과학  PRI4013   07                                                      일반물리학및실험2         박경원    서울                       화4.0-5.0/12:00-13:30,수6.0-7.5/14:00-16:00,목4.0-5.0/12:00-13:30                                                                                     207-623(혜화관  623 강의실),308-325(과학관  일반물리학실험실A),207-623(혜화관  623 강의실)   4     이과대학                     이과대학 물리반도체과학부                                                                          공과대 일괄수강신청 예정 강좌, 수강인원 50명
#   31   학문기초  제4영역:자연과학  PRI4013   08                                                      일반물리학및실험2         김순구    서울                       화1.0-2.5/09:00-11:00,화8.0-9.0/16:00-17:30,목8.5-9.5/16:30-18:00                                                                       308-325(과학관  일반물리학실험실A),102-462(학술/문화관 K462 462 강의실),102-462(학술/문화관 K462 462 강의실)   4     이과대학                     이과대학 물리반도체과학부                                                                          공과대 일괄수강신청 예정 강좌, 수강인원 50명
#   32   학문기초  제4영역:자연과학  PRI4013   09                                                      일반물리학및실험2         이동화    서울                       화4.0-5.5/12:00-14:00,화6.0-7.0/14:00-15:30,금6.0-7.0/14:00-15:30                                                                       308-325(과학관  일반물리학실험실A),102-454(학술/문화관 K454 454 강의실),102-454(학술/문화관 K454 454 강의실)   4     이과대학                     이과대학 물리반도체과학부                                                                          공과대 일괄수강신청 예정 강좌, 수강인원 50명
#   33   학문기초  제4영역:자연과학  PRI4013   10                                                      일반물리학및실험2         오형택    서울                       수4.5-5.5/12:30-14:00,수8.0-9.5/16:00-18:00,금4.0-5.0/12:00-13:30                                                                               408-321(정보문화관Q Q301 강의실),308-325(과학관  일반물리학실험실A),408-321(정보문화관Q Q301 강의실)   4     이과대학                     이과대학 물리반도체과학부                                                                           공과대 일괄수강신청 예정 강좌,수강인원 50명
#   34   학문기초  제4영역:자연과학  PRI4013   11                                                      일반물리학및실험2         류영선    서울                                        수10.0-12.5/18:00-20:30,수13.0-14.5/20:40-22:20                                                                                                           308-303(과학관 D303 강의실),308-325(과학관  일반물리학실험실A)   4     이과대학                     이과대학 물리반도체과학부                                                                          공과대 일괄수강신청 예정 강좌, 수강인원 50명
#   35   학문기초  제4영역:자연과학  PRI4013   12                                                      일반물리학및실험2         권상우    서울                                        목10.0-12.5/18:00-20:30,목13.0-14.5/20:40-22:20                                                                                                           308-303(과학관 D303 강의실),308-325(과학관  일반물리학실험실A)   4     이과대학                     이과대학 물리반도체과학부                                                                                            수강인원 50명
#   36   학문기초  제4영역:자연과학  PRI4013   13                                                      일반물리학및실험2         NaN    서울                       수6.0-7.5/14:00-16:00,목4.0-5.0/12:00-13:30,금4.0-5.0/12:00-13:30                                                                               407-109(정보문화관P P304 강의실),407-109(정보문화관P P304 강의실),308-325(과학관  일반물리학실험실A)   4     이과대학                     이과대학 물리반도체과학부                                                                                            수강인원 50명
#   37   학문기초  제4영역:자연과학  PRI4014   01                                                       일반화학및실험2         김갑수    서울                       월2.5-3.5/10:30-12:00,월4.0-5.5/12:00-14:00,화2.5-3.5/10:30-12:00                                                                              407-B101(정보문화관P P201 강의실),308-407(과학관  일반화학실험실A),407-B101(정보문화관P P201 강의실)   4     이과대학                          이과대학 화학과                                                                일괄수강수강정원 40명 제한, 신청 예정(화학과, 화공생물공학과)
#   38   학문기초  제4영역:자연과학  PRI4014   02                                                       일반화학및실험2         임재희    서울                       월2.0-3.5/10:00-12:00,월4.0-5.0/12:00-13:30,수3.0-4.0/11:00-12:30                                                                                      308-407(과학관  일반화학실험실A),501-231(학림관 J201 강의실),501-231(학림관 J201 강의실)   4     이과대학                          이과대학 화학과                                                                      수강정원 40명 제한, 일괄수강신청예정(화공생물공학과)
#   39   학문기초  제4영역:자연과학  PRI4014   03                                                       일반화학및실험2         유미경    서울                       화4.0-5.0/12:00-13:30,화5.5-7.0/13:30-15:30,목4.0-5.0/12:00-13:30                                                                        407-203(정보문화관P P401 강의실_스마트),308-407(과학관  일반화학실험실A),407-203(정보문화관P P401 강의실_스마트)   4     이과대학                          이과대학 화학과                                                                  수강신청 40명 제한, 일괄수강신청예정(융합에너지신소재공학과)
#   40   학문기초  제4영역:자연과학  PRI4014   04                                                       일반화학및실험2         김갑수    서울                                          월8.0-9.5/16:00-18:00,월10.0-12.5/18:00-20:30                                                                                                        308-407(과학관  일반화학실험실A),407-B122(정보문화관P P205 강의실)   4     이과대학                          이과대학 화학과                                                                 수강신청 40명 제한, 일괄수강신청예정(화학과, 화공생물공학과)
#   41   학문기초  제4영역:자연과학  PRI4014   05                                                       일반화학및실험2         김갑수    서울                       화5.5-6.5/13:30-15:00,목5.5-6.5/13:30-15:00,목7.0-8.5/15:00-17:00                                                                        407-203(정보문화관P P401 강의실_스마트),407-203(정보문화관P P401 강의실_스마트),308-407(과학관  일반화학실험실A)   4     이과대학                          이과대학 화학과                                                                          수강신청 40명 제한, 일괄수강신청예정(화학과)
#   42   학문기초  제4영역:자연과학  PRI4014   06                                                       일반화학및실험2         이길선    일산                                            수6.0-8.5/14:00-17:00,금6.0-7.5/14:00-16:00                                                                                         1104-845(상영바이오관 845 세미나실1(고양캠퍼스)),1104-266(상영바이오관 266 학부 공용실습실)   4     이과대학                          이과대학 화학과                                                                                  수강신청 40명 제한, BMC개설
#   43   학문기초  제4영역:자연과학  PRI4014   07                                                       일반화학및실험2         윤성욱    서울                       수4.5-5.5/12:30-14:00,금2.0-3.5/10:00-12:00,금4.0-5.0/12:00-13:30                                                                                207-324(혜화관 324 324 강의실),308-407(과학관  일반화학실험실A),207-324(혜화관 324 324 강의실)   4     이과대학                          이과대학 화학과                                                                                         수강신청 40명 제한
#   44   학문기초  제4영역:자연과학  PRI4014   08                                                       일반화학및실험2         조대행    일산                                            목7.0-9.5/15:00-18:00,금2.0-3.5/10:00-12:00                                                                                                  1104-213(상영바이오관 213 강의실),1104-266(상영바이오관 266 학부 공용실습실)   4     이과대학                          이과대학 화학과                                                                                  수강신청 40명 제한, BMC개설
#   45   학문기초  제4영역:자연과학  PRI4015   01                                                      일반생물학및실험2         이보영    서울                                            화8.0-9.5/16:00-18:00,금6.0-7.5/14:00-16:00                                                                                            401-2158(신공학관(기숙사) 2158 일반생물학실험실),201-111(사회과학/경영관 M111 강의실)   3 바이오시스템대학                   바이오시스템대학 생명과학과                                                                                                  팀티칭
#   46   학문기초  제4영역:자연과학  PRI4015   02                                                      일반생물학및실험2         정상민    서울                                        월10.0-11.5/18:00-19:40,월12.0-13.5/19:40-21:30                                                                                             407-B127(정보문화관P P207 강의실),401-2158(신공학관(기숙사) 2158 일반생물학실험실)   3 바이오시스템대학                   바이오시스템대학 생명과학과                                                                                                  NaN
#   47   학문기초  제4영역:자연과학  PRI4015   03                                                      일반생물학및실험2         김병혁    일산                                            월6.0-7.5/14:00-16:00,월8.0-9.5/16:00-18:00                                                                                               1102-206(종합강의동 206 강의실),1104-245(상영바이오관 245 생명과학과 전공 실습실)   3 바이오시스템대학                   바이오시스템대학 생명과학과                                                                                                BMC개설
#   48   학문기초  제4영역:자연과학  PRI4015   04                                                      일반생물학및실험2         조선희    서울                                            화1.0-2.5/09:00-11:00,목6.5-8.0/14:30-16:30                                                                                            202-364(사회과학/경영관 L311 강의실),401-2158(신공학관(기숙사) 2158 일반생물학실험실)   3 바이오시스템대학                   바이오시스템대학 생명과학과                                                                                                  팀티칭
#   49   학문기초  제4영역:자연과학  PRI4016   01                                                      일반통계학및실습2          정선    서울                                            화6.0-7.5/14:00-16:00,수6.0-7.5/14:00-16:00                                                                                               407-B108(정보문화관P P203 강의실),102-211(학술/문화관 K211 (K) 공용컴퓨터실)   3     이과대학                        이과대학 통계학과                                                                                     일반통계학및실습1 선이수 권장
#   50   학문기초  제4영역:자연과학  PRI4021   01                                                      대학생물학및실험2         정상민    일산                       화1.0-2.0/09:00-10:30,수6.0-7.5/14:00-16:00,목1.0-2.0/09:00-10:30                                                       1104-845(상영바이오관 845 세미나실1(고양캠퍼스)),1104-266(상영바이오관 266 학부 공용실습실),1104-845(상영바이오관 845 세미나실1(고양캠퍼스))   4 바이오시스템대학                   바이오시스템대학 생명과학과                                                                                            BMC개설 팀티칭
#   51   학문기초  제4영역:자연과학  PRI4021   02                                                      대학생물학및실험2         정상민    일산                       화2.5-3.5/10:30-12:00,수8.0-9.5/16:00-18:00,목2.5-3.5/10:30-12:00                                                       1104-845(상영바이오관 845 세미나실1(고양캠퍼스)),1104-266(상영바이오관 266 학부 공용실습실),1104-845(상영바이오관 845 세미나실1(고양캠퍼스))   4 바이오시스템대학                   바이오시스템대학 생명과학과                                                                                            BMC개설 팀티칭
#   52   학문기초  제4영역:자연과학  PRI4021   03                                                      대학생물학및실험2         변지희    일산                      화2.5-3.5/10:30-12:00,화8.5-10.0/16:30-18:25,목2.5-3.5/10:30-12:00                                                                       1102-132(종합강의동 132 세미나실1),1104-266(상영바이오관 266 학부 공용실습실),1102-132(종합강의동 132 세미나실1)   4 바이오시스템대학                   바이오시스템대학 생명과학과                                                                                            BMC개설 팀티칭
#   53   학문기초  제4영역:자연과학  PRI4021   04                                                      대학생물학및실험2         방석영    일산                       월2.5-3.5/10:30-12:00,화4.0-5.5/12:00-14:00,수2.5-3.5/10:30-12:00                                                       1104-848(상영바이오관 848 세미나실2(고양캠퍼스)),1104-266(상영바이오관 266 학부 공용실습실),1104-848(상영바이오관 848 세미나실2(고양캠퍼스))   4 바이오시스템대학                   바이오시스템대학 생명과학과                                                                                                BMC개설
#   54   학문기초  제4영역:자연과학  PRI4021   05                                                      대학생물학및실험2         변지희    일산                       월5.0-6.5/13:00-15:00,화1.0-2.0/09:00-10:30,목1.0-2.0/09:00-10:30                                                                       1104-266(상영바이오관 266 학부 공용실습실),1102-132(종합강의동 132 세미나실1),1102-132(종합강의동 132 세미나실1)   4 바이오시스템대학                   바이오시스템대학 생명과학과                                                                                            BMC개설 팀티칭
#   55   학문기초  제4영역:자연과학  PRI4022   01                                                      대학통계학및실습2         안홍엽    서울                       월2.5-3.5/10:30-12:00,수2.5-3.5/10:30-12:00,금4.0-5.5/12:00-14:00                                                                         307-124(명진관  첨단강의실_스마트),307-124(명진관  첨단강의실_스마트),102-211(학술/문화관 K211 (K) 공용컴퓨터실)   4     이과대학                        이과대학 통계학과                                                                   통계학과 신입생 우선배정 강좌, 대학통계학및실습1 선이수 권장
#   56   학문기초  제4영역:자연과학  PRI4023   01                                                         확률및통계학         김희경    서울                                            월4.0-5.0/12:00-13:30,수3.0-4.0/11:00-12:30                                                                                                       207-324(혜화관 324 324 강의실),207-324(혜화관 324 324 강의실)   3     이과대학                        이과대학 통계학과                                                                                                  NaN
#   57   학문기초  제4영역:자연과학  PRI4023   02                                                         확률및통계학          정선    서울                                            화4.0-5.0/12:00-13:30,목4.0-5.0/12:00-13:30                                                                                                       207-315(혜화관 315 315 강의실),207-315(혜화관 315 315 강의실)   3     이과대학                        이과대학 통계학과                                                                                                  NaN
#   58   학문기초  제4영역:자연과학  PRI4023   03                                                         확률및통계학         곽화륜    서울                                                               월10.0-12.5/18:00-20:30                                                                                                                               307-115(명진관 A115 강의실_스마트)   3     이과대학                        이과대학 통계학과                                                                                                  NaN
#   59   학문기초  제4영역:자연과학  PRI4023   04                                                         확률및통계학         곽화륜    서울                                                               수10.0-12.5/18:00-20:30                                                                                                                               307-115(명진관 A115 강의실_스마트)   3     이과대학                        이과대학 통계학과                                                                                                  NaN
#   60   학문기초  제4영역:자연과학  PRI4023   05                                                         확률및통계학         최은희    일산                                                                화8.0-10.5/16:00-18:50                                                                                                                                 1102-219(종합강의동 219 강의실)   3     이과대학                        이과대학 통계학과                                                                                                BMC개설
#   61   학문기초  제4영역:자연과학  PRI4023   06                                                         확률및통계학         최은희    서울                                            월4.0-5.0/12:00-13:30,수3.0-4.0/11:00-12:30                                                                                               102-342(학술/문화관 K342 342 강의실),102-342(학술/문화관 K342 342 강의실)   3     이과대학                        이과대학 통계학과                                                                                                  NaN
#   62   학문기초  제4영역:자연과학  PRI4024   01                                                        공학선형대수학         연미정    서울                                            월8.5-9.5/16:30-18:00,수6.0-7.0/14:00-15:30                                                                                                       408-321(정보문화관Q Q301 강의실),408-321(정보문화관Q Q301 강의실)   3     이과대학                          이과대학 수학과                                                                                                 NaN
#   63   학문기초  제4영역:자연과학  PRI4024   02                                                        공학선형대수학         송윤애    서울                                            화4.0-5.0/12:00-13:30,목4.0-5.0/12:00-13:30                                                                                                       408-329(정보문화관Q Q302 강의실),408-329(정보문화관Q Q302 강의실)   3     이과대학                          이과대학 수학과                                                                                                 NaN
#   64   학문기초  제4영역:자연과학  PRI4024   03                                                        공학선형대수학         송윤애    서울                                            화6.0-7.0/14:00-15:30,금6.0-7.0/14:00-15:30                                                                                                             307-333(명진관 A333 강의실),307-333(명진관 A333 강의실)   3     이과대학                          이과대학 수학과                                                                                                 NaN
#   65   학문기초  제4영역:자연과학  PRI4024   04                                                        공학선형대수학         조영덕    서울                                            수8.0-9.0/16:00-17:30,금8.0-9.0/16:00-17:30                                                                                                 407-105(정보문화관P P301 정보 PBL),407-105(정보문화관P P301 정보 PBL)   3     이과대학                          이과대학 수학과                                                                                         혁신교수법-액티브러닝
#   66   학문기초  제4영역:자연과학  PRI4025   01                                                          공학수학1         조영덕    서울                                            월4.0-5.0/12:00-13:30,수3.0-4.0/11:00-12:30                                                                                                       408-329(정보문화관Q Q302 강의실),408-329(정보문화관Q Q302 강의실)   3     이과대학                          이과대학 수학과                                                                                                 NaN
#   67   학문기초  제4영역:자연과학  PRI4025   02                                                          공학수학1         최광호    서울                                            월8.5-9.5/16:30-18:00,수6.0-7.0/14:00-15:30                                                                                                       408-329(정보문화관Q Q302 강의실),408-329(정보문화관Q Q302 강의실)   3     이과대학                          이과대학 수학과                                                                                                 NaN
#   68   학문기초  제4영역:자연과학  PRI4025   03                                                          공학수학1         김동호    서울                                            화8.0-9.0/16:00-17:30,목8.5-9.5/16:30-18:00                                                                                               102-352(학술/문화관 K352 352 강의실),102-352(학술/문화관 K352 352 강의실)   3     이과대학                          이과대학 수학과                                                                                                 NaN
#   69   학문기초  제4영역:자연과학  PRI4025   04                                                          공학수학1         조범규    서울                                            수8.0-9.0/16:00-17:30,금8.0-9.0/16:00-17:30                                                                                                       408-321(정보문화관Q Q301 강의실),408-321(정보문화관Q Q301 강의실)   3     이과대학                          이과대학 수학과                                                                                                 NaN
#   70   학문기초  제4영역:자연과학  PRI4027   01                                                           이산수학         김동우    서울                                            수4.5-5.5/12:30-14:00,금4.0-5.0/12:00-13:30                                                                                                     407-B122(정보문화관P P205 강의실),407-B122(정보문화관P P205 강의실)   3     공과대학           공과대학 컴퓨터정보통신공학부 컴퓨터공학전공                                                                                      혁신교수법(플립러닝) 강의
#   71   학문기초  제4영역:자연과학  PRI4028   01                                                          생물학개론         이보영    서울                                            월8.5-9.5/16:30-18:00,수6.0-7.0/14:00-15:30                                                                                                             501-203(학림관 J212 강의실),501-203(학림관 J212 강의실)   3 바이오시스템대학                   바이오시스템대학 생명과학과                                                                                                  NaN
#   72   학문기초  제4영역:자연과학  PRI4028   02                                                          생물학개론         한미희    서울                                            화4.0-5.0/12:00-13:30,목4.0-5.0/12:00-13:30                                                                                                             501-203(학림관 J212 강의실),501-203(학림관 J212 강의실)   3 바이오시스템대학                   바이오시스템대학 생명과학과                                                                                                  NaN
#   73   학문기초  제4영역:자연과학  PRI4028   03                                                          생물학개론         조선희    서울                                            화8.0-9.0/16:00-17:30,목8.5-9.5/16:30-18:00                                                                                                             501-203(학림관 J212 강의실),501-203(학림관 J212 강의실)   3 바이오시스템대학                   바이오시스템대학 생명과학과                                                                                                  NaN
#   74   학문기초  제4영역:자연과학  PRI4028   04                                                          생물학개론         이재영    서울                                                               수10.0-12.5/18:00-20:30                                                                                                                              202-378(사회과학/경영관 L302 강의실)   3 바이오시스템대학                   바이오시스템대학 생명과학과                                                                                                  NaN
#   75   학문기초  제4영역:자연과학  PRI4028   05                                                          생물학개론         이보영    서울                                            수4.5-5.5/12:30-14:00,금4.0-5.0/12:00-13:30                                                                                                   202-571(사회과학/경영관 L501 강의실),202-571(사회과학/경영관 L501 강의실)   3 바이오시스템대학                   바이오시스템대학 생명과학과                                                                                                  NaN
#   76   학문기초  제4영역:자연과학  PRI4029   01                                                          물리학개론         오형택    서울                                            화6.0-7.0/14:00-15:30,금6.0-7.0/14:00-15:30                                                                                                     501-250(학림관 J211 강의실_스마트),501-250(학림관 J211 강의실_스마트)   3     이과대학                     이과대학 물리반도체과학부                                                                                       실험과목 이수자 수강제한
#   77   학문기초  제4영역:자연과학  PRI4029   02                                                          물리학개론         김선배    서울                                                               화10.0-12.5/18:00-20:30                                                                                                                               501-250(학림관 J211 강의실_스마트)   3     이과대학                     이과대학 물리반도체과학부                                                                                       실험과목 이수자 수강제한
#   78   학문기초  제4영역:자연과학  PRI4029   03                                                          물리학개론         이원철    일산                                                                 금5.0-7.5/13:00-16:00                                                                                                                         1104-208(상영바이오관 208 장전 강의실_스마트)   3     이과대학                     이과대학 물리반도체과학부                                                                                BMC개설, 실험과목 이수자 수강제한
#   79   학문기초  제4영역:자연과학  PRI4030   01                                                           화학개론         임재희    서울                                            월6.0-7.0/14:00-15:30,수6.0-7.0/14:00-15:30                                                                                               102-344(학술/문화관 K344 344 강의실),102-344(학술/문화관 K344 344 강의실)   3     이과대학                          이과대학 화학과                                                                                                 NaN
#   80   학문기초  제4영역:자연과학  PRI4030   02                                                           화학개론         문혜영    서울                                            화5.5-6.5/13:30-15:00,목5.5-6.5/13:30-15:00                                                                                                     501-109(학림관 J111 강의실_스마트),501-109(학림관 J111 강의실_스마트)   3     이과대학                          이과대학 화학과                                                                                                 NaN
#   81   학문기초  제4영역:자연과학  PRI4030   03                                                           화학개론         유미경    서울                                            화8.0-9.0/16:00-17:30,목8.5-9.5/16:30-18:00                                                                                                     501-109(학림관 J111 강의실_스마트),501-109(학림관 J111 강의실_스마트)   3     이과대학                          이과대학 화학과                                                                                                 NaN
#   82   학문기초  제4영역:자연과학  PRI4030   04                                                           화학개론         이종혁    서울                                                               수10.0-12.5/18:00-20:30                                                                                                                               501-109(학림관 J111 강의실_스마트)   3     이과대학                          이과대학 화학과                                                                                                 NaN
#   83   학문기초  제4영역:자연과학  PRI4030   05                                                           화학개론         조현진    일산                                                                 화5.5-8.0/13:30-16:30                                                                                                                                 1102-218(종합강의동 218 강의실)   3     이과대학                          이과대학 화학과                                                                                               BMC개설
#   84   학문기초  제4영역:자연과학  PRI4033   01                                                         지구환경과학         조봉연    서울                                            월4.0-5.0/12:00-13:30,수3.0-4.0/11:00-12:30                                                                                                       408-321(정보문화관Q Q301 강의실),408-321(정보문화관Q Q301 강의실)   3     공과대학                      공과대학 건설환경공학과                                                                                                 NaN
#   85   학문기초  제4영역:자연과학  PRI4033   02                                                         지구환경과학         조봉연    서울                                                               수10.0-12.5/18:00-20:30                                                                                                                                408-321(정보문화관Q Q301 강의실)   3     공과대학                      공과대학 건설환경공학과                                                                                                 NaN
#   86   학문기초  제4영역:자연과학  PRI4035   01                                                     프로그래밍기초와실습         홍성옥    서울                                            월4.0-5.5/12:00-14:00,수3.0-4.5/11:00-13:00                                                                                 401-3115(신공학관(기숙사) 3115 (T) 공용컴퓨터실),401-3115(신공학관(기숙사) 3115 (T) 공용컴퓨터실)   3     공과대학           공과대학 컴퓨터정보통신공학부 컴퓨터공학전공                                                                                                 NaN
#   87   학문기초  제4영역:자연과학  PRI4035   02                                                     프로그래밍기초와실습         홍성옥    서울                                           월8.5-10.0/16:30-18:25,수6.0-7.5/14:00-16:00                                                                                 401-3115(신공학관(기숙사) 3115 (T) 공용컴퓨터실),401-3115(신공학관(기숙사) 3115 (T) 공용컴퓨터실)   3     공과대학           공과대학 컴퓨터정보통신공학부 컴퓨터공학전공                                                                                                 NaN
#   88   학문기초  제4영역:자연과학  PRI4035   03                                                     프로그래밍기초와실습         안영아    서울                                            화4.0-5.5/12:00-14:00,목4.0-5.5/12:00-14:00                                                                                         102-211(학술/문화관 K211 (K) 공용컴퓨터실),102-211(학술/문화관 K211 (K) 공용컴퓨터실)   3     공과대학           공과대학 컴퓨터정보통신공학부 컴퓨터공학전공                                                                                                 NaN
#   89   학문기초  제4영역:자연과학  PRI4035   04                                                     프로그래밍기초와실습         정화용    서울                                            수6.5-8.0/14:30-16:30,금6.0-7.5/14:00-16:00                                                                                       405-318(원흥관 1,3 F318 (F) 공용컴퓨터실),405-318(원흥관 1,3 F318 (F) 공용컴퓨터실)   3     공과대학           공과대학 컴퓨터정보통신공학부 컴퓨터공학전공                                                                                                 NaN
#   90   학문기초  제4영역:자연과학  PRI4035   05                                                     프로그래밍기초와실습         정화용    서울                                            수4.5-6.0/12:30-14:30,금4.0-5.5/12:00-14:00                                                                                       405-318(원흥관 1,3 F318 (F) 공용컴퓨터실),405-318(원흥관 1,3 F318 (F) 공용컴퓨터실)   3     공과대학           공과대학 컴퓨터정보통신공학부 컴퓨터공학전공                                                                                                 NaN
#   91   학문기초  제4영역:자연과학  PRI4035   06                                                     프로그래밍기초와실습         김경자    서울                                            수8.0-9.5/16:00-18:00,금8.0-9.5/16:00-18:00                                                                                 401-3115(신공학관(기숙사) 3115 (T) 공용컴퓨터실),401-3115(신공학관(기숙사) 3115 (T) 공용컴퓨터실)   3     공과대학           공과대학 컴퓨터정보통신공학부 컴퓨터공학전공                                                                                                 NaN
#   92   학문기초  제4영역:자연과학  PRI4035   07                                                     프로그래밍기초와실습         안영아    서울                                                               수10.0-13.5/18:00-21:30                                                                                                                     401-3115(신공학관(기숙사) 3115 (T) 공용컴퓨터실)   3     공과대학           공과대학 컴퓨터정보통신공학부 컴퓨터공학전공                                                                                                 NaN
#   93   학문기초  제4영역:자연과학  PRI4039   01                                                       인터넷프로그래밍         윤성림    서울                                            화4.0-5.5/12:00-14:00,목4.0-5.5/12:00-14:00                                                                                     202-463(사회과학/경영관 L432 (L) 공용컴퓨터실),202-463(사회과학/경영관 L432 (L) 공용컴퓨터실)   3     공과대학           공과대학 컴퓨터정보통신공학부 컴퓨터공학전공                                                                                                 NaN
#   94   학문기초  제4영역:자연과학  PRI4039   02                                                       인터넷프로그래밍         장은실    서울                                           화8.0-9.5/16:00-18:00,목8.5-10.0/16:30-18:25                                                                                       405-318(원흥관 1,3 F318 (F) 공용컴퓨터실),405-318(원흥관 1,3 F318 (F) 공용컴퓨터실)   3     공과대학           공과대학 컴퓨터정보통신공학부 컴퓨터공학전공                                                                                                 NaN
# ...
# 2590     교직        NaN  ERC2034   01                                                     종교교재연구및지도법     문현공(혜원)   NaN                                                                 월4.0-6.5/12:00-15:00                                                                                                                                207-337(혜화관 337 337 강의실)   3     불교대학                         불교대학 불교학부                                                                                                 NaN
# 2591     교직        NaN  ERC2035   01                                                     철학교재연구및지도법         이고경    서울                                                               월10.0-12.5/18:00-20:30                                                                                                                                303-143(법학/만해관 B158 강의실)   3     문과대학                          문과대학 철학과                                                                                                 NaN
# 2592     교직        NaN  ERC2036   01                                                     영어교재연구및지도법         신정아    서울                                                                 월5.5-8.0/13:30-16:30                                                                                                                                 307-111(명진관 A111 명진PBL)   3     문과대학              문과대학 영어영문학부 영어통번역학전공                                                                                                 팀티칭
# 2593     교직        NaN  ERC2040   01                                                     물리교재연구및지도법         김형상    서울                                                                 월3.0-5.5/11:00-14:00                                                                                                                                   207-623(혜화관  623 강의실)   3     이과대학                     이과대학 물리반도체과학부                                                                                                 NaN
# 2594     교직        NaN  ERC2041   01                                                     화학교재연구및지도법         이종혁    서울                                                                 수1.0-3.5/09:00-12:00                                                                                                                               307-350(명진관 A350 강의실_스마트)   3     이과대학                          이과대학 화학과                                                                                                 NaN
# 2595     교직        NaN  ERC2042   01                                                   일반사회교재연구및지도법         서창훈    서울                                                                 화1.0-3.5/09:00-12:00                                                                                                                              201-134(사회과학/경영관 M134 강의실)   3   사회과학대학             사회과학대학 정치행정학부 정치외교학전공                                                                                                 NaN
# 2596     교직        NaN  ERC2044   01                                                     농업교재연구및지도법         이경림   NaN                                                                 목6.0-8.5/14:00-17:00                                                                                                                       1104-845(상영바이오관 845 세미나실1(고양캠퍼스))   3 바이오시스템대학                  바이오시스템대학 식품생명공학과                                                                                                 NaN
# 2597     교직        NaN  ERC2045   01                                                     생물교재연구및지도법         조선희    일산                                                                 수2.0-4.5/10:00-13:00                                                                                                                             1104-203(상영바이오관 203 대학원강의실)   3 바이오시스템대학                   바이오시스템대학 생명과학과                                                                                                  NaN
# 2598     교직        NaN  ERC2048   01                                                     미술교재연구및지도법         김지균   NaN                                                                 수1.0-3.5/09:00-12:00                                                                                                                            102-239(학술/문화관 K239 239 강의실)   3     예술대학                        예술대학 미술학부                                                                                                  NaN
# 2599     교직        NaN  ERC2049   01                                                    중국어교재연구및지도법         서미령    서울                                                                 화4.0-6.5/12:00-15:00                                                                                                                                   307-209(명진관 A209 강의실)   3     문과대학                       문과대학 중어중문학과                                                                                                 NaN
# 2600     교직        NaN  ERC2050   01                                                   연극영화교재연구및지도법         안형민    서울                                                               수10.0-12.5/18:00-20:30                                                                                                                             102-223(학술/문화관 K223 문화 PBL)   3     예술대학                         예술대학 연극학부                                                                                    팀티칭, 수강인원 25명 제한
# 2601     교직        NaN  ERC2054   01                                                        교직논리및논술         고희성    서울                                                                 목6.0-8.5/14:00-17:00                                                                                                                                   501-404(학림관 J412 강의실)   3     사범대학                          사범대학 사범대                                                                                         수강인원제한: 35명
# 2602     교직        NaN  ERC2055   01                                                   통합사회교재연구및지도법         이서영   NaN                                                                 수7.0-9.5/15:00-18:00                                                                                                                               501-309(학림관 J312 GIS 강의실)   3     사범대학                        사범대학 지리교육과                                                                                                 NaN
# 2603     교직        NaN  ERC2056   01                                                   통합과학교재연구및지도법         이민호    서울                                                                 월2.0-4.5/10:00-13:00                                                                                                                             501-247(학림관 J210 사범대학 세미나실)   3 바이오시스템대학                   바이오시스템대학 생명과학과                                                                                                  NaN
# 2604     교직        NaN  ERC3010   01                                                    메이커교육의이론과실천         이선희   NaN                                                                 월8.0-9.5/16:00-18:00                                                                                                                                   501-431(학림관 J401 강의실)   2     사범대학                         사범대학 교육학과                                                                                                 NaN
# 2605     교직        NaN  ERC3011   01                                                        교육현장의이해         NaN    서울                                                                                  NaN                                                                                                                                                     NaN   2     사범대학                          사범대학 사범대                                                                                         수강인원제한: 25명
# 2606    군사학        NaN  MRC0006   01                                                    안전및조직관리사례연구         NaN   NaN                                                                                  NaN                                                                                                                                                     NaN   2      NaN                               학군단                                                                                                 NaN
# 2607    군사학        NaN  MRC0008   01                                                      조직리더십사례연구         NaN   NaN                                                                                  NaN                                                                                                                                                     NaN   2      NaN                               학군단                                                                                                 NaN
# 2608   평생교육        NaN  LED0006   01                                                         평생교육실습         장환영   NaN                                                                                  NaN                                                                                                                                                     NaN   3     사범대학                         사범대학 교육학과                                                                                                 NaN
# 2609   평생교육        NaN  LED0007   01                                                        평생교육방법론         이원춘   NaN                                                                 월5.0-7.5/13:00-16:00                                                                                                                                   501-433(학림관 J402 강의실)   3     사범대학                         사범대학 교육학과                                                                                                 NaN
# 2610   평생교육        NaN  LED0013   01                                                        평생교육경영론          김혁   NaN                                                                 월2.0-4.5/10:00-13:00                                                                                                                                207-420(혜화관 420 420 강의실)   3     사범대학                         사범대학 교육학과                                                                                                 NaN
# 2611  나노디그리         이론  NAD1001   01                                                      N-데이터과학개요         이우진   NaN                                                                                  NaN                                                                                                                                                     NaN   1  행정및부속기관                      부속교육기관 SW교육원                                                             사이버강의, 나노디그리 재학생(나노디그리 신청 후 합격자)전용, P/F
# 2612  나노디그리         이론  NAD1002   01                                                   N-기계학습기본알고리즘         김지희   NaN                                                                                  NaN                                                                                                                                                     NaN   1  행정및부속기관                      부속교육기관 SW교육원                                                             사이버강의, 나노디그리 재학생(나노디그리 신청 후 합격자)전용, P/F
# 2613  나노디그리         이론  NAD1003   01                                                     N-데이터시각화개요         장혜령   NaN                                                                                  NaN                                                                                                                                                     NaN   1  행정및부속기관                      부속교육기관 SW교육원                                                             사이버강의, 나노디그리 재학생(나노디그리 신청 후 합격자)전용, P/F
# 2614  나노디그리         이론  NAD1005   01                                                     N-탐색적데이터분석         박성식   NaN                                                                                  NaN                                                                                                                                                     NaN   1  행정및부속기관                      부속교육기관 SW교육원                                                             사이버강의, 나노디그리 재학생(나노디그리 신청 후 합격자)전용, P/F
# 2615  나노디그리         이론  NAD1006   01                                                         N-기계학습         김지희   NaN                                                                                  NaN                                                                                                                                                     NaN   2  행정및부속기관                      부속교육기관 SW교육원                                                             사이버강의, 나노디그리 재학생(나노디그리 신청 후 합격자)전용, P/F
# 2616  나노디그리         이론  NAD1007   01                                                      N-딥러닝알고리즘         김지희   NaN                                                                                  NaN                                                                                                                                                     NaN   1  행정및부속기관                      부속교육기관 SW교육원                                                             사이버강의, 나노디그리 재학생(나노디그리 신청 후 합격자)전용, P/F
# 2617  나노디그리         이론  NAD1008   01                                                  N-추천시스템기본알고리즘         김지희   NaN                                                                                  NaN                                                                                                                                                     NaN   1  행정및부속기관                      부속교육기관 SW교육원                                                             사이버강의, 나노디그리 재학생(나노디그리 신청 후 합격자)전용, P/F
# 2618  나노디그리         이론  NAD1009   01                                                  N-추천시스템고급알고리즘         김지희   NaN                                                                                  NaN                                                                                                                                                     NaN   1  행정및부속기관                      부속교육기관 SW교육원                                                             사이버강의, 나노디그리 재학생(나노디그리 신청 후 합격자)전용, P/F
# 2619  나노디그리        캡스톤  NAD3001   01                                               N-데이터사이언스캡스톤프로젝트         김광일   NaN                                                                 월9.0-9.5/17:00-18:00                                                                                                                             408-229(정보문화관Q Q202 컴퓨터실습실)   1  행정및부속기관                      부속교육기관 SW교육원                        실습, 나노디그리 재학생(나노디그리 신청 후 합격자)전용, 해당 나노디그리 전체 교과목 사전이수자 또는 병수자만 수강 가능, ABCD/F
# 2620  나노디그리        캡스톤  NAD3004   01                                                 N-추천시스템캡스톤프로젝트         김광일   NaN                                                                 화9.0-9.5/17:00-18:00                                                                                                                             408-229(정보문화관Q Q202 컴퓨터실습실)   1  행정및부속기관                      부속교육기관 SW교육원                        실습, 나노디그리 재학생(나노디그리 신청 후 합격자)전용, 해당 나노디그리 전체 교과목 사전이수자 또는 병수자만 수강 가능, ABCD/F

# %% [markdown]
# 다중값 제거(제4정규형) - 강의실

# %%
df_split = df[['번호', '강의실']]

df_split
# Out:
#         번호                                                강의실
# 0        1                                                NaN
# 1        2  102-352(학술/문화관 K352 352 강의실),102-352(학술/문화관 K3...
# 2        3                              307-309(명진관 A309 강의실)
# 3        4  407-109(정보문화관P P304 강의실),407-109(정보문화관P P304 강의실)
# 4        5  102-217(학술/문화관 K217 217 강의실),102-217(학술/문화관 K2...
# ...    ...                                                ...
# 2615  2616                                                NaN
# 2616  2617                                                NaN
# 2617  2618                                                NaN
# 2618  2619                        408-229(정보문화관Q Q202 컴퓨터실습실)
# 2619  2620                        408-229(정보문화관Q Q202 컴퓨터실습실)
#
# [2620 rows x 2 columns]

# %%
# '강의실' 컬럼의 값을 ','를 기준으로 분리하여 새로운 행으로 만들기
df_split = df_split.assign(강의실=df_split['강의실'].str.split(',')).explode('강의실', ignore_index=True)

df_split
# Out:
#         번호                           강의실
# 0        1                           NaN
# 1        2  102-352(학술/문화관 K352 352 강의실)
# 2        2  102-352(학술/문화관 K352 352 강의실)
# 3        3         307-309(명진관 A309 강의실)
# 4        4      407-109(정보문화관P P304 강의실)
# ...    ...                           ...
# 3990  2616                           NaN
# 3991  2617                           NaN
# 3992  2618                           NaN
# 3993  2619   408-229(정보문화관Q Q202 컴퓨터실습실)
# 3994  2620   408-229(정보문화관Q Q202 컴퓨터실습실)
#
# [3995 rows x 2 columns]

# %% [markdown]
# 다중값 제거(제4정규형) - 시간

# %%
df_split2 = df[['번호', '요일/시간']]

df_split2 = df_split2.assign(요일시간=df_split2['요일/시간'].str.split(',')).explode('요일시간', ignore_index=True)

df_split2.drop(columns=['요일/시간'], inplace=True)

df_split2
# Out:
#         번호                   요일시간
# 0        1                    NaN
# 1        2   월4.0-5.0/12:00-13:30
# 2        2   수3.0-4.0/11:00-12:30
# 3        3  월7.0-11.5/15:00-19:40
# 4        4   월4.0-5.0/12:00-13:30
# ...    ...                    ...
# 3770  2616                    NaN
# 3771  2617                    NaN
# 3772  2618                    NaN
# 3773  2619   월9.0-9.5/17:00-18:00
# 3774  2620   화9.0-9.5/17:00-18:00
#
# [3775 rows x 2 columns]

# %%
# '요일'과 '시간'을 추출하는 함수 (NaN 값 예외 처리)
def extract_day_and_time(input_string):
    try:
        day = input_string[0]  # 첫 번째 문자가 요일 정보입니다.
        time = input_string[1:].split('/')[0]  # '/'로 분리하여 두 번째 부분이 시간 정보입니다.
        return day, time
    except:
        return np.NaN, np.NaN

# %%
df_split2['요일'] = df_split2['요일시간'].apply(extract_day_and_time).str[0]
df_split2['시간'] = df_split2['요일시간'].apply(extract_day_and_time).str[1]

df_split2.drop(columns=["요일시간"], inplace=True)

df_split2
# Out:
#         번호   요일        시간
# 0        1  NaN       NaN
# 1        2    월   4.0-5.0
# 2        2    수   3.0-4.0
# 3        3    월  7.0-11.5
# 4        4    월   4.0-5.0
# ...    ...  ...       ...
# 3770  2616  NaN       NaN
# 3771  2617  NaN       NaN
# 3772  2618  NaN       NaN
# 3773  2619    월   9.0-9.5
# 3774  2620    화   9.0-9.5
#
# [3775 rows x 3 columns]

# %%
df_split2[['시작시간', '종료시간']] = df_split2['시간'].str.split('-', n=1, expand=True)

df_split2.drop(columns=['시간'], inplace=True)

df_split2
# Out:
#         번호   요일 시작시간  종료시간
# 0        1  NaN  NaN   NaN
# 1        2    월  4.0   5.0
# 2        2    수  3.0   4.0
# 3        3    월  7.0  11.5
# 4        4    월  4.0   5.0
# ...    ...  ...  ...   ...
# 3770  2616  NaN  NaN   NaN
# 3771  2617  NaN  NaN   NaN
# 3772  2618  NaN  NaN   NaN
# 3773  2619    월  9.0   9.5
# 3774  2620    화  9.0   9.5
#
# [3775 rows x 4 columns]

# %%
df.drop(columns=['요일/시간', '강의실'], inplace=True)

df
# Out:
#         번호   교과과정     교과영역구분     학수코드 학수번호              교과목명  교원명 수업캠퍼스  학점  \
# 0        1   학문기초  제4영역:자연과학  PRI4001   01          미적분학및연습1  문환표    서울   3
# 1        2   학문기초  제4영역:자연과학  PRI4001   02          미적분학및연습1  박장희    서울   3
# 2        3   학문기초  제4영역:자연과학  PRI4002   01         일반물리학및실험1  조훈영    서울   4
# 3        4   학문기초  제4영역:자연과학  PRI4012   01          미적분학및연습2  엄건애    서울   3
# 4        5   학문기초  제4영역:자연과학  PRI4012   02          미적분학및연습2  최광호    서울   3
# ...    ...    ...        ...      ...  ...               ...  ...   ...  ..
# 2615  2616  나노디그리         이론  NAD1007   01         N-딥러닝알고리즘  김지희   NaN   1
# 2616  2617  나노디그리         이론  NAD1008   01     N-추천시스템기본알고리즘  김지희   NaN   1
# 2617  2618  나노디그리         이론  NAD1009   01     N-추천시스템고급알고리즘  김지희   NaN   1
# 2618  2619  나노디그리        캡스톤  NAD3001   01  N-데이터사이언스캡스톤프로젝트  김광일   NaN   1
# 2619  2620  나노디그리        캡스톤  NAD3004   01    N-추천시스템캡스톤프로젝트  김광일   NaN   1
#
#          개설대학        개설학과/전공  \
# 0        이과대학       이과대학 수학과
# 1        이과대학       이과대학 수학과
# 2        이과대학  이과대학 물리반도체과학부
# 3        이과대학       이과대학 수학과
# 4        이과대학       이과대학 수학과
# ...       ...            ...
# 2615  행정및부속기관   부속교육기관 SW교육원
# 2616  행정및부속기관   부속교육기관 SW교육원
# 2617  행정및부속기관   부속교육기관 SW교육원
# 2618  행정및부속기관   부속교육기관 SW교육원
# 2619  행정및부속기관   부속교육기관 SW교육원
#
#                                                      비고
# 0                                                 사이버강의
# 1                                                   NaN
# 2                                         팀티칭, 수강정원 50명
# 3                                                   NaN
# 4                                      공과대 일괄수강신청 예정 강좌
# ...                                                 ...
# 2615            사이버강의, 나노디그리 재학생(나노디그리 신청 후 합격자)전용, P/F
# 2616            사이버강의, 나노디그리 재학생(나노디그리 신청 후 합격자)전용, P/F
# 2617            사이버강의, 나노디그리 재학생(나노디그리 신청 후 합격자)전용, P/F
# 2618  실습, 나노디그리 재학생(나노디그리 신청 후 합격자)전용, 해당 나노디그리 전체 교...
# 2619  실습, 나노디그리 재학생(나노디그리 신청 후 합격자)전용, 해당 나노디그리 전체 교...
#
# [2620 rows x 12 columns]

# %% [markdown]
# 컬럼 이름 변경(DB 테이블 컬럼명으로 변경)

# %%
df_rename_dicts = {
    "번호" : "lecture_id",
    "교과과정" : "lecture_curriculum",
    "교과영역구분" : "lecture_classification",
    "학수코드" : "lecture_code",
    "학수번호" : "lecture_number",
    "교과목명" : "lecture_name",
    "교원명" : "lecture_professor",
    "수업캠퍼스" : "lecture_campus",
    "학점" : "lecture_credit",
    "개설대학" : "lecture_univ",
    "개설학과/전공" : "lecture_major",
    "비고" : "lecture_remark",
}

df.rename(columns=df_rename_dicts, inplace=True)

df
# Out:
#       lecture_id lecture_curriculum lecture_classification lecture_code  \
# 0              1               학문기초              제4영역:자연과학      PRI4001
# 1              2               학문기초              제4영역:자연과학      PRI4001
# 2              3               학문기초              제4영역:자연과학      PRI4002
# 3              4               학문기초              제4영역:자연과학      PRI4012
# 4              5               학문기초              제4영역:자연과학      PRI4012
# ...          ...                ...                    ...          ...
# 2615        2616              나노디그리                     이론      NAD1007
# 2616        2617              나노디그리                     이론      NAD1008
# 2617        2618              나노디그리                     이론      NAD1009
# 2618        2619              나노디그리                    캡스톤      NAD3001
# 2619        2620              나노디그리                    캡스톤      NAD3004
#
#      lecture_number      lecture_name lecture_professor lecture_campus  \
# 0                01          미적분학및연습1               문환표             서울
# 1                02          미적분학및연습1               박장희             서울
# 2                01         일반물리학및실험1               조훈영             서울
# 3                01          미적분학및연습2               엄건애             서울
# 4                02          미적분학및연습2               최광호             서울
# ...             ...               ...               ...            ...
# 2615             01         N-딥러닝알고리즘               김지희            NaN
# 2616             01     N-추천시스템기본알고리즘               김지희            NaN
# 2617             01     N-추천시스템고급알고리즘               김지희            NaN
# 2618             01  N-데이터사이언스캡스톤프로젝트               김광일            NaN
# 2619             01    N-추천시스템캡스톤프로젝트               김광일            NaN
#
#       lecture_credit lecture_univ  lecture_major  \
# 0                  3         이과대학       이과대학 수학과
# 1                  3         이과대학       이과대학 수학과
# 2                  4         이과대학  이과대학 물리반도체과학부
# 3                  3         이과대학       이과대학 수학과
# 4                  3         이과대학       이과대학 수학과
# ...              ...          ...            ...
# 2615               1      행정및부속기관   부속교육기관 SW교육원
# 2616               1      행정및부속기관   부속교육기관 SW교육원
# 2617               1      행정및부속기관   부속교육기관 SW교육원
# 2618               1      행정및부속기관   부속교육기관 SW교육원
# 2619               1      행정및부속기관   부속교육기관 SW교육원
#
#                                          lecture_remark
# 0                                                 사이버강의
# 1                                                   NaN
# 2                                         팀티칭, 수강정원 50명
# 3                                                   NaN
# 4                                      공과대 일괄수강신청 예정 강좌
# ...                                                 ...
# 2615            사이버강의, 나노디그리 재학생(나노디그리 신청 후 합격자)전용, P/F
# 2616            사이버강의, 나노디그리 재학생(나노디그리 신청 후 합격자)전용, P/F
# 2617            사이버강의, 나노디그리 재학생(나노디그리 신청 후 합격자)전용, P/F
# 2618  실습, 나노디그리 재학생(나노디그리 신청 후 합격자)전용, 해당 나노디그리 전체 교...
# 2619  실습, 나노디그리 재학생(나노디그리 신청 후 합격자)전용, 해당 나노디그리 전체 교...
#
# [2620 rows x 12 columns]

# %%
df_split_rename_dicts = {
    "번호" : "lecture_id_id",
    "강의실" : "lecture_room"
}

df_split.rename(columns=df_split_rename_dicts, inplace=True)

df_split
# Out:
#       lecture_id_id                  lecture_room
# 0                 1                           NaN
# 1                 2  102-352(학술/문화관 K352 352 강의실)
# 2                 2  102-352(학술/문화관 K352 352 강의실)
# 3                 3         307-309(명진관 A309 강의실)
# 4                 4      407-109(정보문화관P P304 강의실)
# ...             ...                           ...
# 3990           2616                           NaN
# 3991           2617                           NaN
# 3992           2618                           NaN
# 3993           2619   408-229(정보문화관Q Q202 컴퓨터실습실)
# 3994           2620   408-229(정보문화관Q Q202 컴퓨터실습실)
#
# [3995 rows x 2 columns]

# %%
df_split2_rename_dicts = {
    "번호" : "lecture_id_id",
    "요일" : "lecture_day",
    "시작시간" : "lecture_start_time",
    "종료시간" : "lecture_end_time"  
}

df_split2.rename(columns=df_split2_rename_dicts, inplace=True)

df_split2
# Out:
#       lecture_id_id lecture_day lecture_start_time lecture_end_time
# 0                 1         NaN                NaN              NaN
# 1                 2           월                4.0              5.0
# 2                 2           수                3.0              4.0
# 3                 3           월                7.0             11.5
# 4                 4           월                4.0              5.0
# ...             ...         ...                ...              ...
# 3770           2616         NaN                NaN              NaN
# 3771           2617         NaN                NaN              NaN
# 3772           2618         NaN                NaN              NaN
# 3773           2619           월                9.0              9.5
# 3774           2620           화                9.0              9.5
#
# [3775 rows x 4 columns]

# %% [markdown]
# df를 DB 테이블에 연결

# %%
from sqlalchemy import create_engine
db_config = {
    'user' : 'root',
    'password' : '1234',
    'host' : 'localhost',
    'port' : 3306,
    'name' : 'selfproject'
}

# %%
engine = create_engine(f"mysql+mysqlconnector://{db_config['user']}:{db_config['password']}@{db_config['host']}/{db_config['name']}")

# %%
df.to_sql('appsearch_lecture', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\mysql\connector\connection_cext.py:633, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     632         query = query.encode("utf-8")
# --> 633     self._cmysql.query(
#     634         query,
#     635         raw=raw,
#     636         buffered=buffered,
#     637         raw_as_string=raw_as_string,
#     638         query_attrs=self.query_attrs,
#     639     )
#     640 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Duplicate entry '1' for key 'myapp_lecture.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\sqlalchemy\engine\base.py:1934, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1933     if not evt_handled:
# -> 1934         self.dialect.do_executemany(
#    1935             cursor,
#    1936             str_statement,
#    1937             effective_parameters,
#    1938             context,
#    1939         )
#    1940 elif not effective_parameters and context.no_parameters:
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\sqlalchemy\engine\default.py:918, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     917 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 918     cursor.executemany(statement, parameters)
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\mysql\connector\cursor_cext.py:455, in CMySQLCursor.executemany(self, operation, seq_params)
#     454         self._executed = stmt
# --> 455         return self.execute(stmt)
#     457 rowcnt = 0
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\mysql\connector\cursor_cext.py:330, in CMySQLCursor.execute(self, operation, params, multi)
#     329 try:
# --> 330     result = self._cnx.cmd_query(
#     331         stmt,
#     332         raw=self._raw,
#     333         buffered=self._buffered,
#     334         raw_as_string=self._raw_as_string,
#     335     )
#     336 except MySQLInterfaceError as err:
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py:77, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      76 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 77     return method(cnx, *args, **kwargs)
#      79 current_span = trace.get_current_span()
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\mysql\connector\connection_cext.py:641, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     640 except MySQLInterfaceError as err:
# --> 641     raise get_mysql_exception(
#     642         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     643     ) from err
#     644 except AttributeError as err:
#
# IntegrityError: 1062 (23000): Duplicate entry '1' for key 'myapp_lecture.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 df.to_sql('myapp_lecture', con=engine, if_exists='append', index=False)
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\pandas\core\generic.py:2878, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2713 """
#    2714 Write records stored in a DataFrame to a SQL database.
#    2715
#    (...)
#    2874 [(1,), (None,), (2,)]
#    2875 """  # noqa:E501
#    2876 from pandas.io import sql
# -> 2878 return sql.to_sql(
#    2879     self,
#    2880     name,
#    2881     con,
#    2882     schema=schema,
#    2883     if_exists=if_exists,
#    2884     index=index,
#    2885     index_label=index_label,
#    2886     chunksize=chunksize,
#    2887     dtype=dtype,
#    2888     method=method,
#    2889 )
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\pandas\io\sql.py:769, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     764     raise NotImplementedError(
#     765         "'frame' argument should be either a Series or a DataFrame"
#     766     )
#     768 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 769     return pandas_sql.to_sql(
#     770         frame,
#     771         name,
#     772         if_exists=if_exists,
#     773         index=index,
#     774         index_label=index_label,
#     775         schema=schema,
#     776         chunksize=chunksize,
#     777         dtype=dtype,
#     778         method=method,
#     779         engine=engine,
#     780         **engine_kwargs,
#     781     )
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\pandas\io\sql.py:1920, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1908 sql_engine = get_engine(engine)
#    1910 table = self.prep_table(
#    1911     frame=frame,
#    1912     name=name,
#    (...)
#    1917     dtype=dtype,
#    1918 )
# -> 1920 total_inserted = sql_engine.insert_records(
#    1921     table=table,
#    1922     con=self.con,
#    1923     frame=frame,
#    1924     name=name,
#    1925     index=index,
#    1926     schema=schema,
#    1927     chunksize=chunksize,
#    1928     method=method,
#    1929     **engine_kwargs,
#    1930 )
#    1932 self.check_case_sensitive(name=name, schema=schema)
#    1933 return total_inserted
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\pandas\io\sql.py:1470, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1468 if re.search(msg, err_text):
#    1469     raise ValueError("inf cannot be used with MySQL") from err
# -> 1470 raise err
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\pandas\io\sql.py:1461, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1458 from sqlalchemy import exc
#    1460 try:
# -> 1461     return table.insert(chunksize=chunksize, method=method)
#    1462 except exc.StatementError as err:
#    1463     # GH34431
#    1464     # https://stackoverflow.com/a/67358288/6067848
#    1465     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1466     )|inf can not be used with MySQL"""
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\pandas\io\sql.py:1023, in SQLTable.insert(self, chunksize, method)
#    1020     break
#    1022 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1023 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1024 # GH 46891
#    1025 if is_integer(num_inserted):
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\pandas\io\sql.py:929, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     917 """
#     918 Execute SQL statement inserting data
#     919
#    (...)
#     926    Each item contains a list of values to be inserted
#     927 """
#     928 data = [dict(zip(keys, row)) for row in data_iter]
# --> 929 result = conn.execute(self.table.insert(), data)
#     930 return result.rowcount
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\sqlalchemy\engine\base.py:1412, in Connection.execute(self, statement, parameters, execution_options)
#    1410     raise exc.ObjectNotExecutableError(statement) from err
#    1411 else:
# -> 1412     return meth(
#    1413         self,
#    1414         distilled_parameters,
#    1415         execution_options or NO_OPTIONS,
#    1416     )
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\sqlalchemy\sql\elements.py:483, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     481     if TYPE_CHECKING:
#     482         assert isinstance(self, Executable)
# --> 483     return connection._execute_clauseelement(
#     484         self, distilled_params, execution_options
#     485     )
#     486 else:
#     487     raise exc.ObjectNotExecutableError(self)
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\sqlalchemy\engine\base.py:1635, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1623 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1624     "compiled_cache", self.engine._compiled_cache
#    1625 )
#    1627 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1628     dialect=dialect,
#    1629     compiled_cache=compiled_cache,
#    (...)
#    1633     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1634 )
# -> 1635 ret = self._execute_context(
#    1636     dialect,
#    1637     dialect.execution_ctx_cls._init_compiled,
#    1638     compiled_sql,
#    1639     distilled_parameters,
#    1640     execution_options,
#    1641     compiled_sql,
#    1642     distilled_parameters,
#    1643     elem,
#    1644     extracted_params,
#    1645     cache_hit=cache_hit,
#    1646 )
#    1647 if has_events:
#    1648     self.dispatch.after_execute(
#    1649         self,
#    1650         elem,
#    (...)
#    1654         ret,
#    1655     )
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\sqlalchemy\engine\base.py:1844, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1839     return self._exec_insertmany_context(
#    1840         dialect,
#    1841         context,
#    1842     )
#    1843 else:
# -> 1844     return self._exec_single_context(
#    1845         dialect, context, statement, parameters
#    1846     )
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\sqlalchemy\engine\base.py:1984, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1981     result = context._setup_result_proxy()
#    1983 except BaseException as e:
# -> 1984     self._handle_dbapi_exception(
#    1985         e, str_statement, effective_parameters, cursor, context
#    1986     )
#    1988 return result
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\sqlalchemy\engine\base.py:2339, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2337 elif should_wrap:
#    2338     assert sqlalchemy_exception is not None
# -> 2339     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2340 else:
#    2341     assert exc_info[1] is not None
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\sqlalchemy\engine\base.py:1934, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1932                 break
#    1933     if not evt_handled:
# -> 1934         self.dialect.do_executemany(
#    1935             cursor,
#    1936             str_statement,
#    1937             effective_parameters,
#    1938             context,
#    1939         )
#    1940 elif not effective_parameters and context.no_parameters:
#    1941     if self.dialect._has_events:
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\sqlalchemy\engine\default.py:918, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     917 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 918     cursor.executemany(statement, parameters)
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\mysql\connector\cursor_cext.py:455, in CMySQLCursor.executemany(self, operation, seq_params)
#     453     if stmt is not None:
#     454         self._executed = stmt
# --> 455         return self.execute(stmt)
#     457 rowcnt = 0
#     458 try:
#     459     # When processing read ops (e.g., SELECT), rowcnt is updated
#     460     # based on self._rowcount. For write ops (e.g., INSERT) is
#     461     # updated based on self._affected_rows.
#     462     # The variable self._description is None for write ops, that's
#     463     # why we use it as indicator for updating rowcnt.
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\mysql\connector\cursor_cext.py:330, in CMySQLCursor.execute(self, operation, params, multi)
#     325             raise ProgrammingError(
#     326                 "Not all parameters were used in the SQL statement"
#     327             )
#     329 try:
# --> 330     result = self._cnx.cmd_query(
#     331         stmt,
#     332         raw=self._raw,
#     333         buffered=self._buffered,
#     334         raw_as_string=self._raw_as_string,
#     335     )
#     336 except MySQLInterfaceError as err:
#     337     raise get_mysql_exception(
#     338         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     339     ) from err
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py:77, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      75 """Context propagation decorator."""
#      76 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 77     return method(cnx, *args, **kwargs)
#      79 current_span = trace.get_current_span()
#      80 tp_header = None
#
# File c:\Users\장우진\Desktop\새 폴더\venv\lib\site-packages\mysql\connector\connection_cext.py:641, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     633     self._cmysql.query(
#     634         query,
#     635         raw=raw,
#    (...)
#     638         query_attrs=self.query_attrs,
#     639     )
#     640 except MySQLInterfaceError as err:
# --> 641     raise get_mysql_exception(
#     642         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     643     ) from err
#     644 except AttributeError as err:
#     645     addr = (
#     646         self._unix_socket if self._unix_socket else f"{self._host}:{self._port}"
#     647     )
#
# IntegrityError: (mysql.connector.errors.IntegrityError) 1062 (23000): Duplicate entry '1' for key 'myapp_lecture.PRIMARY'
# [SQL: INSERT INTO myapp_lecture (lecture_id, lecture_curriculum, lecture_classification, lecture_code, lecture_number, lecture_name, lecture_professor, lecture_campus, lecture_credit, lecture_univ, lecture_major, lecture_remark) VALUES (%(lecture_id)s, %(lecture_curriculum)s, %(lecture_classification)s, %(lecture_code)s, %(lecture_number)s, %(lecture_name)s, %(lecture_professor)s, %(lecture_campus)s, %(lecture_credit)s, %(lecture_univ)s, %(lecture_major)s, %(lecture_remark)s)]
# [parameters: [{'lecture_id': 1, 'lecture_curriculum': '학문기초', 'lecture_classification': '제4영역:자연과학', 'lecture_code': 'PRI4001', 'lecture_number': '01', 'lecture_name': '미적분학및연습1', 'lecture_professor': '문환표', 'lecture_campus': '서울', 'lecture_credit': 3, 'lecture_univ': '이과대학', 'lecture_major': '이과대학 수학과', 'lecture_remark': '사이버강의'}, {'lecture_id': 2, 'lecture_curriculum': '학문기초', 'lecture_classification': '제4영역:자연과학', 'lecture_code': 'PRI4001', 'lecture_number': '02', 'lecture_name': '미적분학및연습1', 'lecture_professor': '박장희', 'lecture_campus': '서울', 'lecture_credit': 3, 'lecture_univ': '이과대학', 'lecture_major': '이과대학 수학과', 'lecture_remark': None}, {'lecture_id': 3, 'lecture_curriculum': '학문기초', 'lecture_classification': '제4영역:자연과학', 'lecture_code': 'PRI4002', 'lecture_number': '01', 'lecture_name': '일반물리학및실험1', 'lecture_professor': '조훈영', 'lecture_campus': '서울', 'lecture_credit': 4, 'lecture_univ': '이과대학', 'lecture_major': '이과대학 물리반도체과학부', 'lecture_remark': '팀티칭, 수강정원 50명'}, {'lecture_id': 4, 'lecture_curriculum': '학문기초', 'lecture_classification': '제4영역:자연과학', 'lecture_code': 'PRI4012', 'lecture_number': '01', 'lecture_name': '미적분학및연습2', 'lecture_professor': '엄건애', 'lecture_campus': '서울', 'lecture_credit': 3, 'lecture_univ': '이과대학', 'lecture_major': '이과대학 수학과', 'lecture_remark': None}, {'lecture_id': 5, 'lecture_curriculum': '학문기초', 'lecture_classification': '제4영역:자연과학', 'lecture_code': 'PRI4012', 'lecture_number': '02', 'lecture_name': '미적분학및연습2', 'lecture_professor': '최광호', 'lecture_campus': '서울', 'lecture_credit': 3, 'lecture_univ': '이과대학', 'lecture_major': '이과대학 수학과', 'lecture_remark': '공과대 일괄수강신청 예정 강좌'}, {'lecture_id': 6, 'lecture_curriculum': '학문기초', 'lecture_classification': '제4영역:자연과학', 'lecture_code': 'PRI4012', 'lecture_number': '03', 'lecture_name': '미적분학및연습2', 'lecture_professor': '임영빈', 'lecture_campus': '서울', 'lecture_credit': 3, 'lecture_univ': '이과대학', 'lecture_major': '이과대학 수학과', 'lecture_remark': '공과대 일괄수강신청 예정 강좌'}, {'lecture_id': 7, 'lecture_curriculum': '학문기초', 'lecture_classification': '제4영역:자연과학', 'lecture_code': 'PRI4012', 'lecture_number': '04', 'lecture_name': '미적분학및연습2', 'lecture_professor': '심호진', 'lecture_campus': '서울', 'lecture_credit': 3, 'lecture_univ': '이과대학', 'lecture_major': '이과대학 수학과', 'lecture_remark': '공과대 일괄수강신청 예정 강좌'}, {'lecture_id': 8, 'lecture_curriculum': '학문기초', 'lecture_classification': '제4영역:자연과학', 'lecture_code': 'PRI4012', 'lecture_number': '05', 'lecture_name': '미적분학및연습2', 'lecture_professor': '김동호', 'lecture_campus': '서울', 'lecture_credit': 3, 'lecture_univ': '이과대학', 'lecture_major': '이과대학 수학과', 'lecture_remark': '공과대 일괄수강신청 예정 강좌'}  ... displaying 10 of 2620 total bound parameter sets ...  {'lecture_id': 2619, 'lecture_curriculum': '나노디그리', 'lecture_classification': '캡스톤', 'lecture_code': 'NAD3001', 'lecture_number': '01', 'lecture_name': 'N-데이터사이언스캡스톤프로젝트', 'lecture_professor': '김광일', 'lecture_campus': None, 'lecture_credit': 1, 'lecture_univ': '행정및부속기관', 'lecture_major': '부속교육기관 SW교육원', 'lecture_remark': '실습, 나노디그리 재학생(나노디그리 신청 후 합격자)전용, 해당 나노디그리 전체 교과목 사전이수자 또는 병수자만 수강 가능, ABCD/F'}, {'lecture_id': 2620, 'lecture_curriculum': '나노디그리', 'lecture_classification': '캡스톤', 'lecture_code': 'NAD3004', 'lecture_number': '01', 'lecture_name': 'N-추천시스템캡스톤프로젝트', 'lecture_professor': '김광일', 'lecture_campus': None, 'lecture_credit': 1, 'lecture_univ': '행정및부속기관', 'lecture_major': '부속교육기관 SW교육원', 'lecture_remark': '실습, 나노디그리 재학생(나노디그리 신청 후 합격자)전용, 해당 나노디그리 전체 교과목 사전이수자 또는 병수자만 수강 가능, ABCD/F'}]]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
df_split.to_sql('appsearch_lectureroom', con=engine, if_exists='append', index=False)
# Out:
# 3995

# %%
df_split2.to_sql('appsearch_lecturetime', con=engine, if_exists='append', index=False)
# Out:
# 3775

# %%
engine.dispose()
